# %% [markdown]
# # Notebook Instructions
#
# 1. All the <u>code and data files</u> used in this course are available in the downloadable unit of the <u>last section of this course</u>.
# 2. You can run the notebook document sequentially (one cell at a time) by pressing **Shift + Enter**.
# 3. While a cell is running, a [*] is shown on the left. After the cell is run, the output will appear on the next line.
#
# This course is based on specific versions of Python packages. You can find the details of the packages in <a href='https://quantra.quantinsti.com/quantra-notebook' target="_blank" >this manual</a>.

# %% [markdown]
# ## Recent News Headlines
#
# There are various Python APIs such as [Webhose](http://webhose.io/), [NewsAPI](http://newsapi.org/pricing), [News Fetch](https://pypi.org/project/news-fetch/), [GoogleNews](http://pypi.org/project/GoogleNews/) etc. which aggregate news headlines from various media sources. The framework for using these APIs/libraries are somewhat similar.
#
# The general steps are:
#
# 1. Install and import the library
#
# 2. Get API key (Not required in some cases)
#
# 2. Use filters such as keywords, language, timeframe etc.
#
# 3. Fetch articles
#
# To use a specific API/library, you need to read its documentation.
#
#
# In this notebook, you will learn how to fetch news articles from the [GoogleNews](http://pypi.org/project/GoogleNews/). We will follow the below steps:
#
# 1. Import GoogleNews library
# 2. Apply filters
# 3. Fetch the news articles

# %% [markdown]
# ## Import libraries
# Before importing GoogleNews package, you need to install it. You can do that using the pip command.
#
# `!pip install GoogleNews`
#
# Note: For running the above command in console, the '!' sign is not required.

# %%
# Import pandas and numpy
import pandas as pd
import numpy as np

# Import the GoogleNews package to fetch the news articles
from GoogleNews import GoogleNews
googlenews = GoogleNews()

# %% [markdown]
# ## Apply filters
#
# We will apply filters to get the news articles. The filters are:
#
# 1. Keywords: List of the keywords which you want to search it can be anything such as business, stocks, apple, economy.
# 2. Date range: Date up to which you want to fetch articles.
#
# In the below example, we are using keywords related to stock Apple(`AAPL`).

# %%
keywords = ['Apple-Stock', 'Apple-Revenue', 'Apple-Sales', 'Apple', 'AAPL']
googlenews.set_time_range('12/01/2020', '03/10/2021')

# %% [markdown]
# ## Fetch the news articles
#
# We create a dataframe that stores all the relevant information required from a news article, such as date, time, title/headline, description of the news article, and the source.

# %%
# Dataframe to store the news article information
article_info = pd.DataFrame(columns=['Date', 'Time', 'Title', 'Articles', 'Link'])

# Gathering all the data of the current page to one dataframe
def newsfeed1(article_info, raw_dictionary):
    for i in range(len(raw_dictionary)-1):
        if raw_dictionary is not None:
            # Fetch the date and time and convert it into datetime format
            date = raw_dictionary[i]['datetime']
            date = pd.to_datetime(date)
            # Fetch the title, time, description and source of the news articles
            title = raw_dictionary[i]['title']
            time = raw_dictionary[i]['date']
            articles = raw_dictionary[i]['desc']
            link = raw_dictionary[i]['link']
            # Append all the above information in a single dataframe
            article_info = article_info.append({'Date': date, 'Time': time, 'Title': title,
                            'Articles': articles, 'Link': link}, ignore_index=True)
        else:
            break

    return article_info

# %% [markdown]
# We loop over each keyword and get the news articles up to 1 page. In this example, we are fetching news articles for only one page, but you can increase the page number and check the output.

# %%
# Dataframe containing the news of all the keywords searched
articles = pd.DataFrame()

# Each keyword will be searched seperately and results will be saved in a dataframe
for steps in range(len(keywords)):
    string = (keywords[steps])
    googlenews.search(string)

    # Fetch the results
    result = googlenews.results()

    # Number of pages up to which you want to fetch news articles
    total_pages = 1

    for steps in range(total_pages):
        # Variable consists of pages specified by user so using "for loop" to retrieve all the data in dataframe
        googlenews.get_page(steps)
        feed = newsfeed1(article_info, result)
# 89 2020-12-29 00:00:00.000000       29-Dec-2020
# 90 2020-12-29 00:00:00.000000       29-Dec-2020
# 91 2020-12-15 00:00:00.000000       15-Dec-2020
# 92 2020-12-09 00:00:00.000000       09-Dec-2020
# 93 2021-02-03 00:00:00.000000       03-Feb-2021
# 94 2021-03-07 10:51:41.822131       1 month ago
#
#                                                 Title  \
# 0     Just keep buying Apple stock, David Baskin says
# 1   Apple, Twilio Lead Stocks Near Buy Points Afte...
# 2   Should You Buy Apple Stock After The Recent Co...
# 3   Apple stock price target was lifted by Wedbush...
# 4   Is Apple Stock Poised To Rise After Declining ...
# 5   Apple stock rises, Tesla dips after report tha...
# 6   Apple Stock Hits Record High On Bullish 2021 P...
# 7   Apple Stock Sets Record Because Earnings Passi...
# 8   Apple Stock Could Be Blunted By Antitrust Scru...
# 9   Apple Stock Rises On Apple Car Speculation, Bu...
# 10    Just keep buying Apple stock, David Baskin says
# 11  Apple, Twilio Lead Stocks Near Buy Points Afte...
# 12  Should You Buy Apple Stock After The Recent Co...
# 13  Apple stock price target was lifted by Wedbush...
# 14  Is Apple Stock Poised To Rise After Declining ...
# 15  Apple stock rises, Tesla dips after report tha...
# 16  Apple Stock Hits Record High On Bullish 2021 P...
# 17  Apple Stock Sets Record Because Earnings Passi...
# 18  Apple Stock Could Be Blunted By Antitrust Scru...
# 19  Apple revenue crosses $100 billion for first t...
# 20  Apple's revenue surpasses $100 bn-mark in Dec ...
# 21  Apple Earnings (AAPL): Revenue Tops $100 Milli...
# 22                Apple Reports First Quarter Results
# 23  Apple revenue from App Store up 28% to record ...
# 24  Apple Revenue Growing Further After Cupertino-...
# 25  It's being revealed today that Apple's Revenue...
# 26  BREAKING NEWS: Apple Revenue Nears $10 Billion...
# 27  Apple set to post $100bn-revenue quarter after...
# 28                      Apple Earnings: What Happened
# 29  Apple revenue crosses $100 billion for first t...
# ..                                                ...
# 65  Apple takes aim at adtech hysteria over iOS ap...
# 66  Elon Musk says he once considered selling Tesl...
# 67            Apple removes Parler from the App Store
# 68  Apple Has Threatened To Ban Parler From The Ap...
# 69               Apple suspends Parler from App Store
# 70  Apple introduces AirPods Max, the magic of Air...
# 71  Apple announces $549 AirPods Max noise-canceli...
# 72  Apple announces $549 over-ear headphones, the ...
# 73  Apple’s App Tracking Transparency feature will...
# 74  Apple Fitness+: The next era of fitness is her...
# 75  Apple takes aim at adtech hysteria over iOS ap...
# 76  Apple Q1 Preview: Will The iPhone 12 Deliver F...
# 77  AAPL earnings Q1 2021: Analysts expect big thi...
# 78  Wedbush increases AAPL price target to $175 as...
# 79  AAPL shares hit intraday record just shy of $1...
# 80      Is It Full Speed Ahead With Apple (AAPL) Car?
# 81  If Apple (NASDAQ: AAPL) can execute, the next ...
# 82  Apple's Services Will Eclipse The iPhone Jugge...
# 83                   Apple (AAPL) Sells $14B of Bonds
# 84               What Will Drive Apple Stock in 2021?
# 85  Morgan Stanley raises AAPL to $164 on Q1 2021 ...
# 86  Apple Q1 Preview: Will The iPhone 12 Deliver F...
# 87  AAPL earnings Q1 2021: Analysts expect big thi...
# 88  Wedbush increases AAPL price target to $175 as...
# 89  AAPL shares hit intraday record just shy of $1...
# 90      Is It Full Speed Ahead With Apple (AAPL) Car?
# 91  If Apple (NASDAQ: AAPL) can execute, the next ...
# 92  Apple's Services Will Eclipse The iPhone Jugge...
# 93                   Apple (AAPL) Sells $14B of Bonds
# 94               What Will Drive Apple Stock in 2021?
#
#                                              Articles  \
# 0   Apple (Apple Stock Quote, Chart, News NASDAQ:A...
# 1   Apple stock also moved above a 122.09 early en...
# 2   Apple stock (NASDAQ: AAPL) dropped -5.5% over ...
# 3   Meanwhile, Apple's stock slipped 0.1% in prema...
# 4   Apple stock (NASDAQ: AAPL) has declined by aro...
# 5   Apple stock rises, Tesla dips after report tha...
# 6   Apple stock notched a record high on Tuesday a...
# 7   UBS analyst David Vogt maintains a Neutral rat...
# 8   Apple stock is picking up a head of steam on d...
# 9   Apple stock rose Tuesday on a fresh news repor...
# 10  Apple (Apple Stock Quote, Chart, News NASDAQ:A...
# 11  Apple stock also moved above a 122.09 early en...
# 12  Apple stock (NASDAQ: AAPL) dropped -5.5% over ...
# 13  Meanwhile, Apple's stock slipped 0.1% in prema...
# 14  Apple stock (NASDAQ: AAPL) has declined by aro...
# 15  Apple stock rises, Tesla dips after report tha...
# 16  Apple stock notched a record high on Tuesday a...
# 17  UBS analyst David Vogt maintains a Neutral rat...
# 18  Apple stock is picking up a head of steam on d...
# 19  International sales accounted for 64% of the q...
# 20  Apple's revenue for the quarter ended Dec. 26 ...
# 21  Apple Inc. shares slid 2.9% in premarket tradi...
# 22  The Company posted all-time record revenue of ...
# 23  Apple revenue from App Store up 28% to record ...
# 24  Apple's revenue for the quarter ended December...
# 25  It's being revealed today that Apple's Revenue...
# 26  BREAKING NEWS: Apple Revenue Nears $10 Billion...
# 27  A weakened US dollar should help significantly...
# 28  Apple's revenue has climbed year-over-year (YO...
# 29  International sales accounted for 64% of the q...
# ..                                                ...
# 65  Apple has used a speech to European lawmakers ...
# 66  Tesla CEO Elon Musk tweeted on Tuesday, “Durin...
# 67  Apple has removed Parler from the App Store, f...
# 68  Apple has given Parler, the social network fav...
# 69  Apple confirmed that it has suspended the cons...
# 70  With AirPods Max, we are bringing that magical...
# 71  It turns out Apple has one more major hardware...
# 72  Powered by Apple's H1 chip with 10 audio cores...
# 73  The plan is to launch these changes in early s...
# 74  Apple Fitness + Studio workout displayed on iP...
# 75  Apple has used a speech to European lawmakers ...
# 76  Apple (NASDAQ:AAPL) is slated to publish its Q...
# 77  Today will see the announcement of AAPL earnin...
# 78  Wedbush has raised its AAPL price target to $1...
# 79  It looks like AAPL could close out 2020 at a r...
# 80  There are few well-kept secrets in the stock m...
# 81  Apple Inc (NASDAQ:AAPL) has created generation...
# 82  Apple's (NASDAQ:AAPL) Services business is lik...
# 83  Apple Inc. (AAPL) has sold $14 billion of bond...
# 84  That would be a massive coup for AAPL given th...
# 85  Morgan Stanley has raised its AAPL price targe...
# 86  Apple (NASDAQ:AAPL) is slated to publish its Q...
# 87  Today will see the announcement of AAPL earnin...
# 88  Wedbush has raised its AAPL price target to $1...
# 89  It looks like AAPL could close out 2020 at a r...
# 90  There are few well-kept secrets in the stock m...
# 91  Apple Inc (NASDAQ:AAPL) has created generation...
# 92  Apple's (NASDAQ:AAPL) Services business is lik...
# 93  Apple Inc. (AAPL) has sold $14 billion of bond...
# 94  That would be a massive coup for AAPL given th...
#
#                                                  Link
# 0   https://www.cantechletter.com/2020/12/just-kee...
# 1   https://www.investors.com/news/apple-stock-twi...
# 2   https://www.trefis.com/stock/aapl/articles/509...
