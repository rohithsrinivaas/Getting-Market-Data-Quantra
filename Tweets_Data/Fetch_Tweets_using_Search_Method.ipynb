# %% [markdown]
# # Notebook Instructions
#
# 1. All the <u>code and data files</u> used in this course are available in the downloadable unit of the <u>last section of this course</u>.
# 2. You can run the notebook document sequentially (one cell at a time) by pressing **Shift + Enter**.
# 3. While a cell is running, a [*] is shown on the left. After the cell is run, the output will appear on the next line.
#
# This course is based on specific versions of Python packages. You can find the details of the packages in <a href='https://quantra.quantinsti.com/quantra-notebook' target="_blank" >this manual</a>.

# %% [markdown]
# # Fetching tweets
#
# In this notebook, you will learn to
# 1. Get tweets with a specific word in it
# 2. Increase the number of tweets fetched per request
# 3. Get tweet text and full tweet text
# 4. Remove retweets
# 5. Get other information in a tweet such as the retweet count, user screen name and created at
# 5. Keep tweets in English language only
# 5. Remove generic tweets
#
# Note: The output for the code will change during runtime.

# %% [markdown]
# ## Authenticate and create an API object - you already know this!

# %%
# Import libraries
import os
import sys
sys.path.append("..")

# Import the get_twitter_tokens from the FMDA_quantra module
# The code of this module can be found in the downloads (last section) of this course
# You need to edit FMDA_quantra.py file and add your Twitter tokens manually before you continue
from data_modules.FMDA_quantra import get_twitter_tokens

# Method in sentiment_analysis_quantra module to get the dictionary of consumer key and consumer secret
twitter_tokens = get_twitter_tokens()

# Set the consumer key and secret from the twitter_tokens dictionary
consumer_key = twitter_tokens['consumer_key']
consumer_secret = twitter_tokens['consumer_secret']

import tweepy
auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# ## Tweets with specific words in it
#
# The `search` method of the API object can be used to search for the presence of a specific word in the tweet. For example, to search for the word 'AMZN' with a dollar sign in the tweet pass the parameter as shown below to the search method.

# %%
tweets_search_result = api.search(q = '$AMZN')

# %% [markdown]
# The output of the `search` method is the `SearchResults` object. It contains the information of the tweets which match the search criteria. By default, a maximum of 15 recent tweets is returned which matches the search criteria. The output is stored in `tweets_search_result`.

# %%
type(tweets_search_result)
# Out:
# tweepy.models.SearchResults

# %%
tweets_search_result
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000021ADEDD4C88>, _json={'created_at': 'Thu May 20 19:59:12 +0000 2021', 'id': 1395469173820624899, 'id_str': '1395469173820624899', 'text': '$AMZN, Bearish Reversal, at Resistance level R1 , 1 Minute, 15:59', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [{'text': 'AMZN', 'indices': [0, 5]}], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">CBLStocksFeed</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1372005507850964993, 'id_str': '1372005507850964993', 'name': 'CBLStocksFeed', 'screen_name': 'CBLStocksFeed', 'location': '', 'description': 'real time alert for intraday momentum stocks price actions, volume spikes, and support and resistant levels', 'url': 'https://t.co/AEx0Jfheav', 'entities': {'url': {'urls': [{'url': 'https://t.co/AEx0Jfheav', 'expanded_url': 'https://cblstrategies.ca', 'display_url': 'cblstrategies.ca', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 255, 'friends_count': 0, 'listed_count': 4, 'created_at': 'Wed Mar 17 02:03:10 +0000 2021', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 27701, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1372005611211218945/PI-6CZYN_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1372005611211218945/PI-6CZYN_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1372005507850964993/1615946782', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 20, 19, 59, 12), id=1395469173820624899, id_str='1395469173820624899', text='$AMZN, Bearish Reversal, at Resistance level R1 , 1 Minute, 15:59', truncated=False, entities={'hashtags': [], 'symbols': [{'text': 'AMZN', 'indices': [0, 5]}], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source
...
#  Status(_api=<tweepy.api.API object at 0x0000021ADEDD4C88>, _json={'created_at': 'Thu May 20 19:55:32 +0000 2021', 'id': 1395468250914254849, 'id_str': '1395468250914254849', 'text': '#Options Flow Stream Update $AAPL $AMZN $TSLA $UPS $SHOP $PDD $MA $SPY $QQQ $SPX #OptionsTrading #OptionsFlow… https://t.co/DR0BwSgt1E', 'truncated': True, 'entities': {'hashtags': [{'text': 'Options', 'indices': [0, 8]}, {'text': 'OptionsTrading', 'indices': [81, 96]}, {'text': 'OptionsFlow', 'indices': [97, 109]}], 'symbols': [{'text': 'AAPL', 'indices': [28, 33]}, {'text': 'AMZN', 'indices': [34, 39]}, {'text': 'TSLA', 'indices': [40, 45]}, {'text': 'UPS', 'indices': [46, 50]}, {'text': 'SHOP', 'indices': [51, 56]}, {'text': 'PDD', 'indices': [57, 61]}, {'text': 'MA', 'indices': [62, 65]}, {'text': 'SPY', 'indices': [66, 70]}, {'text': 'QQQ', 'indices': [71, 75]}, {'text': 'SPX', 'indices': [76, 80]}], 'user_mentions': [], 'urls': [{'url': 'https://t.co/DR0BwSgt1E', 'expanded_url': 'https://twitter.com/i/web/status/1395468250914254849', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [111, 134]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://www.tickwatcher.com" rel="nofollow">tickwatcher</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4584354895, 'id_str': '4584354895', 'name': 'TickWatcher', 'screen_name': 'MITickWatcher', 'location': 'California, USA', 'description': 'Update for stock earnings, dividend, money flow information for stocks, market and sectors rotation. All in one market and portfolio station with Advanced Alert', 'url': 'https://t.co/TFmFqsPG02', 'entities': {'url': {'urls': [{'url': 'https://t.co/TFmFqsPG02', 'expanded_url': 'http://www.mobileinteractive.com/superstocks', 'display_url': 'mobileinteractive.com/superstocks', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 5174, 'friends_count': 4903, 'listed_count': 76, 'created_at': 'Thu Dec 17 12:19:55 +0000 2015', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 53213, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/893292424285519872/nX9e2WBb_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/893292424285519872/nX9e2WBb_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4584354895/1618961755', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 20, 19, 55, 32), id=1395468250914254849, id_str='1395468250914254849', text='#Options Flow Stream Update $AAPL $AMZN $TSLA $UPS $SHOP $PDD $MA $SPY $QQQ $SPX #OptionsTrading #OptionsFlow… https://t.co/DR0BwSgt1E', truncated=True, entities={'hashtags': [{'text': 'Options', 'indices': [0, 8]}, {'text': 'OptionsTrading', 'indices': [81, 96]}, {'text': 'OptionsFlow', 'indices': [97, 109]}], 'symbols': [{'text': 'AAPL', 'indices': [28, 33]}, {'text': 'AMZN', 'indices': [34, 39]}, {'text': 'TSLA', 'indices': [40, 45]}, {'text': 'U ...
#  Status(_api=<tweepy.api.API object at 0x0000021ADEDD4C88>, _json={'created_at': 'Thu May 20 19:55:18 +0000 2021', 'id': 1395468194874277893, 'id_str': '1395468194874277893', 'text': '@Sarge986 Stephen Guilfoyle with the update on ViacomCBS: The story, the industry, and the #SargePlan  $VIAC $DISCA… https://t.co/CgTCRQ9Dpv', 'truncated': True, 'entities': {'hashtags': [{'text': 'SargePlan', 'indices': [91, 101]}], 'symbols': [{'text': 'VIAC', 'indices': [103, 108]}, {'text': 'DISCA', 'indices': [109, 115]}], 'user_mentions': [{'screen_name': 'Sarge986', 'name': 'Stephen Guilfoyle', 'id': 378334234, 'id_str': '378334234', 'indices': [0, 9]}], 'urls': [{'url': 'https://t.co/CgTCRQ9Dpv', 'expanded_url': 'https://twitter.com/i/web/status/1395468194874277893', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id':
photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 600, 'resize': 'fit'}, 'small': {'w': 680, 'h': 340, 'resize': 'fit'}, 'large': {'w': 1200, 'h': 600, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://maximum-pain.com" rel="nofollow">maxpain</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 716737614771044352, 'id_str': '716737614771044352', 'name': 'max pain', 'screen_name': 'optioncharts', 'location': '', 'description': '', 'url': 'https://t.co/eIsTCt8fCQ', 'entities': {'url': {'urls': [{'url': 'https://t.co/eIsTCt8fCQ', 'expanded_url': 'http://maximum-pain.com', 'display_url': 'maximum-pain.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2336, 'friends_count': 16, 'listed_count': 79, 'created_at': 'Sun Apr 03 21:22:18 +0000 2016', 'favourites_count': 14, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 237143, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/752664674416619520/cdAjb6AU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/752664674416619520/cdAjb6AU_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/716737614771044352/1468284199', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'fav ...
#  Status(_api=<tweepy.api.API object at 0x0000021ADEDD4C88>, _json={'created_at': 'Thu May 20 19:51:02 +0000 2021', 'id': 1395467118645235714, 'id_str': '1395467118645235714', 'text': '$AMZN https://t.co/1MOCGxCvwS', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [{'text': 'AMZN', 'indices': [0, 5]}], 'user_mentions': [], 'urls': [], 'media': [{'id': 1395467108939620353, 'id_str': '1395467108939620353', 'indices': [6, 29], 'media_url': 'http://pbs.twimg.com/media/E12x8SwWYAEwdkZ.png', 'media_url_https': 'https://pbs.twimg.com/media/E12x8SwWYAEwdkZ.png', 'url': 'https://t.co/1MOCGxCvwS', 'display_url': 'pic.twitter.com/1MOCGxCvwS', 'expanded_url': 'https://twitter.com/SwatOptions/status/1395467118645235714/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 356, 'h': 341, 'resize': 'fit'}, 'small': {'w': 356, 'h': 341, 'resize': 'fit'}, 'large': {'w': 356, 'h': 341, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]}, 'extended_entities': {'media': [{'id': 1395467108939620353, 'id_str': '1395467108939620353', 'indices': [6, 29], 'media_url': 'http://pbs.twimg.com/media/E12x8SwWYAEwdkZ.png', 'media_url_https': 'https://pbs.twimg.com/media/E12x8SwWYAEwdkZ.png', 'url': 'https://t.co/1MOCGxCvwS', 'display_url': 'pic.twitter.com/1MOCGxCvwS', 'expanded_url': 'https://twitter.com/SwatOptions/status/1395467118645235714/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 356, 'h': 341, 'resize': 'fit'}, 'small': {'w': 356, 'h': 341, 'resize': 'fit'}, 'large': {'w': 356, 'h': 341, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://www.techsmith.com/screen-capture.asp" rel="nofollow">Snagit</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 106504911, 'id_str': '106504911', 'name': 'SWAT', 'screen_name': 'SwatOptions', 'location': '', 'description': 'Trading for a living #Stocks #Options for 12+ years. Mastering Technical Analysis and #UnusualOptionsActivity . Discord channels available via https://t.co/bb5lDFhphI', 'url': 'https://t.co/DDOVUGT2CR', 'entities': {'url': {'urls': [{'url': 'https://t.co/DDOVUGT2CR', 'expanded_url': 'https://www.swatoptions.com/', 'display_url': 'swatoptions.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/bb5lDFhphI', 'expanded_url': 'http://swatoptions.com', 'display_url': 'swatoptions.com', 'indices': [143, 166]}]}}, 'protected': False, 'followers_count': 40560, 'friends_count': 25, 'listed_count': 682, 'created_at': 'Tue Jan 19 19:48:23 +0000 2010', 'favourites_count': 5898, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 72455, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1342814095582638082/DULLxSx-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1342814095582638082/DULLxSx-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/106504911/1608904046', 'profile_link_color': '009999', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_coun ...
#  Status(_api=<tweepy.api.API object at 0x0000021ADEDD4C88>, _json={'created_at': 'Thu May 20 19:50:57 +0000 2021', 'id': 1395467097812127745, 'id_str': '1395467097812127745', 'text': '$AMZN Fucking BS NQ up 300 points and this cant get over 20$ LMAO', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [{'text': 'AMZN', 'indices': [0, 5]}], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://stocktwits.com" rel="nofollow">StockTwits Web</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2366503370, 'id_str': '2366503370', 'name': 'Johnny Khoshaba', 'screen_name': 'j_khoshaba', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 12, 'friends_count': 14, 'listed_count': 0, 'created_at': 'Sat Mar 01 04:19:51 +0000 2014', 'favourites_count': 51, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 709, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1366952082868211714/vohId4Xv_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1366952082868211714/vohId4Xv_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 20, 19, 50, 57), id=1395467097812127745, id_str='1395467097812127745', text='$AMZN Fucking BS NQ up 300 points and this cant get over 20$ LMAO', truncated=False, entities={'hashtags': [], 'symbols': [{'text': 'AMZN', 'indices': [0, 5]}], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='StockTwits Web', source_url='https://stocktwits.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000021ADEDD4C88>, _json={'id': 2366503370, 'id_str': '2366503370', 'name': 'Johnny Khoshaba', 'screen_name': 'j_khoshaba', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 12, 'friends_count': 14, 'listed_count': 0, 'created_at': 'Sat Mar 01 04:19:51 +0000 2014', 'favourites_count': 51, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 709, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1366952082868211714/vohId4Xv_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1366952082868211714/vohId4Xv_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar ...

# %%
len(tweets_search_result)
# Out:
# 13

# %% [markdown]
# ## Increase the number of tweets fetched
#
# To increase the number of tweets fetched per request, you can use the `count` parameter of the `api.search` method. But you can get a maximum of 100 tweets per request. For example, in the below code the count is set to 150 but only 100 tweets are returned.

# %%
tweets_search_result = api.search(q = '$AMZN', 
                                  count=150)
len(tweets_search_result)
# Out:
# 93

# %% [markdown]
# ## Get the tweet text
#
# For each tweet, it contains information such as tweet text, user screen name, and created date. To fetch the text of the first tweet in the `tweets_search_result` you can use the below code.

# %%
# Store the first tweet information in the tweet variable
tweet = tweets_search_result[0]

# Access the text using the property text of the variable tweet
tweet_text = tweet.text

# Print the text of the tweet
print(tweet_text)
# Out:
# $AMZN, Bearish Reversal, at Resistance level R1 , 1 Minute, 15:59

# %% [markdown]
# ## Get full tweet text
#
# The text of the tweet is truncated and only 140 characters are returned for this tweet. Therefore, if the actual tweet text is more than 140 characters then you will not be able to see the tweet. To fetch full tweet text, you will need to set the `tweet_mode` to `extended` as shown below.

# %%
tweets_search_result = api.search(q = '$AMZN', 
                                  count=100, 
                                  tweet_mode='extended')

tweet = tweets_search_result[0]
print(tweet.full_text)
# Out:
# $AMZN, Bearish Reversal, at Resistance level R1 , 1 Minute, 15:59

# %% [markdown]
# ## Remove retweets
#
# However, this partially solves our problem as the retweets are still truncated to 140 characters. But we have original tweet and number of times it was retweeted. Therefore, we can remove all the retweets by adding `-filter:retweets` in the search string as shown below.

# %%
tweets_search_result = api.search(q = '$AMZN -filter:retweets', 
                                  count=100, 
                                  tweet_mode='extended')

tweet = tweets_search_result[0]
print(tweet.full_text)
# Out:
# $AMZN, Bearish Reversal, at Resistance level R1 , 1 Minute, 15:59

# %% [markdown]
# ## Print tweet information
#
# We have defined a function `print_tweet_info` to print other information such as id: a unique number to identify a tweet, the date and time (UTC) when the tweet was created, user screen name, tweet text, retweet count, favourite count and language of the tweet in a tabular format.

# %%
# tabulate helps to print the data in a tabular format
from tabulate import tabulate

# This function takes as input the tweet (tweepy.models.Status object) and prints information in that tweet.
def print_tweet_info(tweet):      
    tweet_info = [
                    ['Tweet ID: ', tweet.id_str],
                    ['Created At (UTC):', tweet.created_at],
                    ['User Screen Name: ', tweet.user.screen_name],
                    ['Tweet Text: ', tweet.full_text],
                    ['Retweet Count:', tweet.retweet_count],
                    ['Favourite Count:', tweet.favorite_count],
                    ['Language:', tweet.lang],                                   
                ]
    print(tabulate(tweet_info))

# %%
print_tweet_info(tweet)
# Out:
# -----------------  -----------------------------------------------------------------
# Tweet ID:          1395469173820624899
# Created At (UTC):  2021-05-20 19:59:12
# User Screen Name:  CBLStocksFeed
# Tweet Text:        $AMZN, Bearish Reversal, at Resistance level R1 , 1 Minute, 15:59
# Retweet Count:     0
# Favourite Count:   0
# Language:          en
# -----------------  -----------------------------------------------------------------

# %% [markdown]
# ## Keep only tweets in the English language
#
# To keep only the tweets in the English language, add the parameter `language='en'` to the search method.

# %%
tweets_search_result = api.search(q = '$AMZN -filter:retweets', 
                                  count=100, 
                                  tweet_mode='extended', 
                                  language='en')

# %% [markdown]
# ## Remove generic tweets
#
# There are many times when the tweet is generic and not specific to a particular stock and has all the stock tickers mentioned in it. We believe that such tweets help little in determining the sentiment around any stock and should be removed.
#
# You can count for the occurrence of the dollar sign in the tweet using the count method on the tweet text. If the occurrence of the dollar sign is more than 8 then it is a generic tweet and should be removed. Otherwise, the tweet can be kept.
#
# We have shown below two sample tweet, one with many tickers in it and other with only one stock ticker in it.

# %%
tweet_text = "$BBDA draws huge volume and runs up 300%. $WDBG $LFAP $GNCP $SHLDQ $MXMG $MSPC $HPIL $CSOC $SHMP $FTEG $ACB $SGCP $VAPE $WWIO $DRUS $BLSP $WNBD $AAPL $TSLA $FB $DSCR $MSFT $BGFT $IFXY $ADTM $AMZN $SNAP $MLHC $MGTI $BRKK $NNRX $HRI $DMHI $VYST $PMPG https://t.co/n3jsNtItMy"
if tweet_text.count('$') >= 8:
    print("The tweet contains more than 8 tickers")
else:
    print("The tweet doesn't contains more than 8 tickers")
# Out:
# The tweet contains more than 8 tickers

# %%
tweet_text = "$AMZN draws huge volume and is in bull run."
if tweet_text.count('$') >= 8:
    print("The tweet contains more than 8 tickers")
else:
    print("The tweet doesn't contain more than 8 tickers")
# Out:
# The tweet doesn't contain more than 8 tickers

# %% [markdown]
# In the next notebook unit, you will learn how to fetch the tweets posted by a specific user and how to fetch tweets between specific dates.
